# %%
import numpy as np
from src.model.williams_otto import Reactor 
from gekko import GEKKO
import json
import matplotlib.pyplot as plt
plt.style.use('ggplot')

r = Reactor()
m = r.getModel()

# general options
m.time = np.linspace(0,5,100)
m.options.CV_TYPE = 2 # squared error
m.options.IMODE = 6 # control

m.solve(disp=True)
# Out:
# apm 138.59.218.22_gk_model16 <br><pre> ----------------------------------------------------------------
#  APMonitor, Version 0.9.2
#  APMonitor Optimization Suite
#  ----------------------------------------------------------------
#
#
#  --------- APM Model Size ------------
#  Each time step contains
#    Objects      :            0
#    Constants    :            3
#    Variables    :           11
#    Intermediates:            5
#    Connections  :            0
#    Equations    :           11
#    Residuals    :            6
#
#  Number of state variables:           5445
#  Number of total equations: -         4950
#  Number of slack variables: -            0
#  ---------------------------------------
#  Degrees of freedom       :            495
#
#  **********************************************
#  Dynamic Control with Interior Point Solver
#  **********************************************
#
#
#  Info: Exact Hessian
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.10, running with linear solver ma57.
#
# Number of nonzeros in equality constraint Jacobian...:    17209
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:     6732
#
# Reallocating memory for MA57: lfact (241206)
# Total number of variables............................:     5445
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      693
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:     4950
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.9800000e+03 9.90e+03 0.00e+00   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  9.4025550e+02 9.22e+03 1.73e+01  -0.3 1.56e+04    -  3.51e-02 5.25e-01f  1
#    2  6.2303754e+02 6.53e+03 1.10e+01  -5.4 5.29e+03    -  4.29e-01 3.37e-01f  1
#    3  5.0662822e+02 5.37e+03 7.66e+00  -1.6 5.60e+03    -  5.69e-01 1.87e-01h  1
#    4  1.6606007e-01 1.06e+03 8.22e+00  -1.2 5.27e+03    -  9.46e-02 1.00e+00f  1
#    5 -1.9918446e-01 1.03e-02 2.69e+00  -2.2 1.06e+03    -  9.08e-01 1.00e+00h  1
#    6  2.0252058e-03 2.02e-02 1.93e-01  -3.2 6.00e+01    -  9.25e-01 1.00e+00h  1
#    7  1.3276431e-03 2.68e-01 4.07e-02  -3.7 8.98e+01    -  8.20e-01 1.00e+00h  1
#    8  7.1328659e-04 8.65e+01 3.99e-02  -3.0 3.88e+02    -  2.16e-01 4.56e-01h  1
#    9  5.1839014e-04 2.87e+01 4.53e-03  -3.0 3.31e+02    -  6.20e-01 7.53e-01h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.1637919e-04 6.49e+01 2.63e-04  -3.0 2.92e+02    -  1.00e+00 1.00e+00h  1
#   11  1.5064449e-04 3.14e+01 1.09e-05  -3.0 7.25e+01    -  1.00e+00 1.00e+00h  1
#   12  1.4895711e-04 1.57e-02 1.08e-08  -3.0 3.02e+01    -  1.00e+00 1.00e+00h  1
#   13  8.7031242e-05 5.56e-02 9.04e-04  -4.4 1.28e+01    -  9.24e-01 1.00e+00h  1
#   14  2.6501482e-05 2.81e-01 8.10e-06  -5.0 2.42e+01    -  9.98e-01 1.00e+00h  1
#   15  8.3597170e-06 1.52e-02 8.79e-07  -6.0 6.82e+00    -  9.98e-01 1.00e+00h  1
#   16  5.9889259e-07 2.14e-02 7.59e-08  -7.2 3.80e+00    -  1.00e+00 1.00e+00h  1
#   17  2.6042847e-08 7.63e-02 2.60e-08  -8.2 4.76e+00    -  9.95e-01 1.00e+00h  1
# Reallocating memory for MA57: lfact (253854)
#   18  6.2982772e-10 1.34e-02 1.77e-10  -8.2 2.13e+00    -  1.00e+00 1.00e+00h  1
#   19  5.9589549e-10 1.80e-05 7.41e-14  -8.2 6.01e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  7.7744507e-13 3.37e-04 2.74e-10 -11.0 3.30e-01    -  9.96e-01 1.00e+00h  1
#   21  1.3313574e-14 4.73e-07 1.77e-14 -10.6 1.27e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.3313574180227328e-14    1.3313574180227328e-14
# Dual infeasibility......:   1.7709238741274953e-14    1.7709238741274953e-14
# Constraint violation....:   4.7328593666406960e-07    4.7328593666406960e-07
# Complementarity.........:   2.6671560188296185e-11    2.6671560188296185e-11
# Overall NLP error.......:   4.7328593666406960e-07    4.7328593666406960e-07
#
#
# Number of objective function evaluations             = 22
# Number of objective gradient evaluations             = 22
# Number of equality constraint evaluations            = 22
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 22
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 21
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.534
# Total CPU secs in NLP function evaluations           =      1.197
#
# EXIT: Optimal Solution Found.
#
#  The solution was found.
#
#  The final value of the objective function is   1.331357418022733E-014
#
#  ---------------------------------------------------
#  Solver         :  IPOPT (v3.12)
#  Solution time  :    1.89330000001064      sec
#  Objective      :   1.331357418022733E-014
#  Successful solution
#  ---------------------------------------------------

# %%
with open(m.path+'//results.json') as f:
    results = json.load(f)
results.keys()
# Out:
# dict_keys(['time', 'i39', 'i40', 'i41', 'k1', 'k2', 'k3', 'm', 'v', 'fa', 'fb', 'tr', 'ma', 'mb', 'mc', 'me', 'mp', 'mg', 'eta', 'mu', 'ma.tau', 'ma.tr', 'ma.sp', 'ma.err2', 'ma.bias', 'ma.bcv', 'ma.wsp', 'ma.cost', 'mb.tau', 'mb.tr', 'mb.sp', 'mb.err2', 'mb.bias', 'mb.bcv', 'mb.wsp', 'mb.cost', 'mc.tau', 'mc.tr', 'mc.sp', 'mc.err2', 'mc.bias', 'mc.bcv', 'mc.wsp', 'mc.cost', 'me.tau', 'me.tr', 'me.sp', 'me.err2', 'me.bias', 'me.bcv', 'me.wsp', 'me.cost', 'mp.tau', 'mp.tr', 'mp.sp', 'mp.err2', 'mp.bias', 'mp.bcv', 'mp.wsp', 'mp.cost', 'mg.tau', 'mg.tr', 'mg.sp', 'mg.err2', 'mg.bias', 'mg.bcv', 'mg.wsp', 'mg.cost', 'eta.tau', 'eta.tr', 'eta.sp', 'eta.err2', 'eta.bias', 'eta.bcv', 'eta.wsp', 'eta.cost', 'mu.tau', 'mu.tr', 'mu.sp', 'mu.err2', 'mu.bias', 'mu.bcv', 'mu.wsp', 'mu.cost'])

# %%
plt.figure()
plt.plot(results['time'], results['k2'])
plt.legend(['k1'])

plt.figure()
plt.plot(results['time'], results['tr'])
plt.legend(['tr'])

plt.figure()
plt.plot(results['time'], results['fa'])
plt.plot(results['time'], results['fb'])
plt.legend(['fa','fb'])

plt.figure()
plt.plot(results['time'], results['ma'])
plt.plot(results['time'], results['mb'])
plt.plot(results['time'], results['mc'])
plt.plot(results['time'], results['me'])
plt.plot(results['time'], results['mp'])
plt.plot(results['time'], results['mg'])
#plt.plot(results['time'], results['mu'])
plt.legend(['ma','mb','mc','me','mp','mg'])

plt.figure()
plt.plot(results['time'], results['ma'])
plt.plot(results['time'], results['ma.tr'])
plt.plot(results['time'], results['ma.sp'])
plt.legend(['ma','tr','sp'])

plt.figure()
plt.plot(results['time'], results['mg'])
plt.plot(results['time'], results['mg.tr'])
plt.plot(results['time'], results['mg.sp'])
plt.legend(['mg','tr','sp'])
